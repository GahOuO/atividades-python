# %% [markdown]
# <a href="https://colab.research.google.com/github/GahOuO/atividades-python/blob/main/Atividade2_ALP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Questões Resolvidas

# %% [markdown]
# ## 1. Maior e menor entre vários valores
#
# *   Leia 6 números inteiros e informe o maior e o menor valor digitado. Não utilize max() nem min().

# %% [markdown]
# Raciocínio:
# 1. Leia o primeiro número e use-o para inicializar maior e menor.
# 2. Leia os outros 5 valores.
# 3. Atualize maior somente quando surgir um valor maior.
# 4. Atualize menor somente quando surgir um valor menor.

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa ler 6 números inteiros, comparando-os a cada leitura para obter qual seria o maior ou o menor entre eles.
# 2. Terá a entrada de 6 números inteiros, armazenamento dos números maiores e menores digitados momentâneamente e a saída do maior e menor número digitado.
# 3.
# 4.
# 5.

# %%
primeiro = int(input("Digite um número: "))
maior = primeiro
menor = primeiro
for i in range(5):
 numero = int(input("Digite um número: "))
 if numero > maior:
  maior = numero
 if numero < menor:
  menor = numero
print("Maior:", maior)
print("Menor:", menor)
# Out:
# Digite um número: 8
# Digite um número: 3
# Digite um número: 12
# Digite um número: -2
# Digite um número: 7
# Digite um número: 5
# Maior: 12
# Menor: -2

# %% [markdown]
# ## 2. Estatísticas de uma turma
#
#
# *   Leia as notas de 5 alunos. Ao final, mostre a média da turma, quantos tiveram nota maior ou
# igual a 7 e quantos tiveram nota menor que 7.

# %% [markdown]
# Raciocínio:
#
# 5. Use um acumulador para a soma das notas.
# 6. Use contadores para as duas situações.
# 7. Na mesma repetição, some a nota e classifique o aluno.
# 8. Calcule a média somente após as 5 leituras.

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 3. Validando uma entrada
#
#
# *   Peça uma nota entre 0 e 10. Enquanto o valor estiver fora desse intervalo, solicite uma nova
# nota. Quando uma nota válida for informada, mostre-a.

# %% [markdown]
# Raciocínio:
#
# 9. Leia uma nota.
# 10. Enquanto ela for inválida, solicite outra.
# 11. O laço termina quando a condição de invalidez se torna falsa.

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## 4. Estacionamento
#
#
# -   Um estacionamento cobra R\$ 8,00 por até 2 horas. Acima de 2 e até 5 horas, cobra R\$ 8,00 mais
# R\$ 3,00 por hora adicional. Acima de 5 horas, cobra R\S 17,00 mais R\$ 2,00 por hora que
# ultrapassar 5. Leia a quantidade inteira de horas e calcule o valor a pagar.

# %% [markdown]
# **Antes de programar**\
# O cálculo é igual para todas as quantidades de horas?\
# Quais faixas de cobrança existem?

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 6. Maior valor e sua posição
#
#
# *   Leia 8 números inteiros. Informe o maior valor e a posição em que ele apareceu pela primeira
# vez. \
# - **Exemplo:**\
# 7, 12, 5, 20, 8, 20, 3, 9 → maior 20; primeira posição 4.

# %% [markdown]
# **Antes de programar**\
# Quando surge um novo maior, quais duas informações precisam mudar juntas?

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 7. Segundo maior valor
# - Leia 8 números inteiros distintos e informe o maior e o segundo maior. Não utilize max(), sort()
# ou listas.

# %% [markdown]
# **Antes de programar**\
# Quando aparece um novo maior, o que acontece com o antigo maior?

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 8. Detectando repetição consecutiva
# - Leia 8 números inteiros e informe se em algum momento foram digitados dois valores iguais
# consecutivamente. Não é necessário informar quais valores foram iguais.

# %% [markdown]
# **Exemplo:**\
# 4, 7, 3, 3, 9, 2, 5, 8 → existem valores consecutivos iguais.\
# **Antes de programar**\
# É necessário guardar todos os 8 valores?\
# Que informação da leitura anterior precisa permanecer disponível?

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 9. Controle de saldo
# - O programa começa com saldo de R$ 500,00. Serão realizadas 6 operações. Em cada uma, leia
# o tipo (1 = depósito; 2 = saque) e o valor. Depósitos aumentam o saldo. Saques só podem
# ocorrer se houver saldo suficiente; caso contrário, mostre 'Saldo insuficiente'. Ao final, mostre o
# saldo.

# %% [markdown]
# **Antes de programar**\
# O saldo é um contador, um acumulador ou o estado atual do sistema?\
# O que deve acontecer quando um saque não puder ser realizado?

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 10. Caixa eletrônico simplificado
# - Leia um valor inteiro positivo e informe a menor quantidade de cédulas para representá-lo,
# usando R$ 100, 50, 20, 10, 5, 2 e 1.

# %% [markdown]
# **Antes de programar**\
# Que operadores permitem descobrir quantas cédulas cabem e quanto resta?

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 11. Número primo
# - Leia um inteiro maior que 1 e informe se ele é primo.

# %% [markdown]
# **Antes de programar**\
# Como podemos procurar evidência de que um número não é primo?

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 12. Divisores de um número
# - Leia um inteiro positivo N, mostre todos os seus divisores positivos e informe quantos divisores
# ele possui.

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 13. Números primos em um intervalo
# - Leia A e B positivos, com A < B, mostre os primos entre A e B (inclusive) e informe quantos foram
# encontrados.

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 14. Jogo com limite de tentativa
# - Considere o número secreto 37. O usuário terá no máximo 5 tentativas. Após cada erro, informe
# se o secreto é maior ou menor que o palpite. Termine ao acertar ou ao usar as 5 tentativas.

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## 15. Desafio final - caixa de atendimento
# - Um caixa inicia o dia com R$ 200,00. Leia operações até que o código 0 seja informado. Código 1
# = entrada de dinheiro; código 2 = retirada. Para cada operação válida, leia o valor. Uma retirada
# só é permitida se houver saldo suficiente. Ao final, informe: saldo final, quantidade de entradas,
# quantidade de retiradas realizadas, quantidade de retiradas recusadas, total que entrou e total
# que saiu

# %% [markdown]
# **Resolução:**
#
#
# 1. O programa precisa
# 2.
# 3.
# 4.
# 5.
