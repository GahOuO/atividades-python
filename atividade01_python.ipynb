# %% [markdown]
# <a href="https://colab.research.google.com/github/GahOuO/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade 01 — Introdução ao Python

# %%
print("Olá, mundo!")
print("Curso Técnico em Informática")
# Out:
# Olá, mundo!
# Curso Técnico em Informática

# %%
disciplina = input("Digite o nome da disciplina: ")
conteudo = input("Digite o conteúdo estudado: ")
atividade = input("Digite o número da atividade: ")
print("\n--- Informações da atividade ---")
print("Disciplina:", disciplina)
print("Conteúdo:", conteudo)
print("Atividade:", atividade)
# Out:
# Digite o nome da disciplina: Matemática
# Digite o conteúdo estudado: PA e PG
# Digite o número da atividade: 02
#
# --- Informações da atividade ---
# Disciplina: Matemática
# Conteúdo: PA e PG
# Atividade: 02

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado:", soma)
# Out:
# Resultado: 30
